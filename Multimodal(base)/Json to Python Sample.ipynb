# %%
import json
import numpy as np
import pandas as pd
with open("C:/Users/user/OneDrive/Desktop/연구실/002.대용량콘텐츠_sample/라벨링데이터/en_health_20190102021355_20_594_1201262_720_output_H264_2974.json","r") as sample_json:
    sp_python = json.load(sample_json)

sp_python
# Out:
# [{'video_id': '301805',
#   'metas': [{'category_0': '1',
#     'category_1': '007',
#     'category_2': '011',
#     'category_3': '007',
#     'start_frame': 0,
#     'end_frame': 99,
#     'bbox_list': [[541.25, 478.4375, 50, 50],
#      [541, 478.68749999999994, 50, 50],
#      [540.75, 478.93749999999994, 50, 50],
#      [540.5, 479.18749999999994, 50, 50],
#      [540.25, 479.43749999999994, 50, 50],
#      [540, 479.6874999999999, 50, 50],
#      [539.75, 479.9374999999999, 50, 50],
#      [539.5000000000001, 480.1874999999999, 50, 50],
#      [539.2500000000001, 480.4374999999999, 50, 50],
#      [539.0000000000001, 480.68749999999983, 50, 50],
#      [538.75, 480.9375, 50, 50],
#      [538.5, 479.8125, 50, 50],
#      [538.25, 478.68750000000006, 50, 50],
#      [538, 477.56250000000006, 50, 50],
#      [537.75, 476.4375000000001, 50, 50],
#      [537.5, 475.3125000000001, 50, 50],
#      [537.25, 474.18750000000017, 50, 50],
# ...

# %%
spDF = pd.DataFrame(sp_python)

spDF1 = pd.DataFrame(data=[list(sp_python.values())],columns=list(sp_python.keys()))

spDF1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-355741888b71> in <module>
#       1 spDF = pd.DataFrame(sp_python)
#       2
# ----> 3 spDF1 = pd.DataFrame(data=[list(sp_python.values())],columns=list(sp_python.keys()))
#       4
#       5 spDF1
#
# AttributeError: 'list' object has no attribute 'values'
